# %% [markdown]
# # Data

# %%
# !ls data/gender_model_input/trainA | head
# Out:
# 20_0_0_20170104020603909.jpg.chip.jpg
# 20_0_0_20170104230025073.jpg.chip.jpg
# 20_0_0_20170104230042553.jpg.chip.jpg
# 20_0_0_20170104230048181.jpg.chip.jpg
# 20_0_0_20170104230051977.jpg.chip.jpg
# 20_0_0_20170104230054071.jpg.chip.jpg
# 20_0_0_20170105161704786.jpg.chip.jpg
# 20_0_0_20170105161706251.jpg.chip.jpg
# 20_0_0_20170105183430767.jpg.chip.jpg
# 20_0_0_20170105184038831.jpg.chip.jpg
# ls: write error: Broken pipe

# %% [markdown]
# trainA is for whites and trainB is for blacks

# %%
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import random


def show_imgs(path, num=5, figsize=(20,10), columns=5):
    images = []
    paths = glob.glob(path+"/*")
    paths = [paths[random.randrange(len(paths))] for item in range(num)]
    for img_path in paths:
        images.append(mpimg.imread(img_path))
    plt.figure(figsize=figsize)
    for i, image in enumerate(images):
        plt.subplot(len(images) / columns + 1, columns, i + 1)
        plt.imshow(image)

# %%
show_imgs('data/gender_model_input/trainA')

# %%
show_imgs('data/gender_model_input/trainB')

# %% [markdown]
# # Modules

# %%
from __future__ import division
import os
import time
from glob import glob
import tensorflow as tf
import numpy as np
from collections import namedtuple
import tensorflow as tf
import tensorflow.contrib.slim as slim
import math
import numpy as np
import pprint
import scipy.misc
import copy

# %%
def lrelu(x, leak=0.2, name="lrelu"):
    return tf.maximum(x, leak*x)

# %%
def instance_norm(input, name="instance_norm"):
    with tf.variable_scope(name):
        depth = input.get_shape()[3]           # Number of channels.

        # Average 1, standard deviation 0.02 nomal distribution, ie number of channels.
        scale = tf.get_variable("scale", [depth], initializer=tf.random_normal_initializer(1.0, 0.02, dtype=tf.float32))

        # Create variable for the number of channels.
        offset = tf.get_variable("offset", [depth], initializer=tf.constant_initializer(0.0))

        mean, variance = tf.nn.moments(input, axes=[1,2], keep_dims=True)       # Find the mean and variance for the width and height.
        epsilon = 1e-5
        inv = tf.rsqrt(variance + epsilon)
        normalized = (input-mean)*inv
        return scale*normalized + offset

# %%
def conv2d(input_, output_dim, ks=4, s=2, stddev=0.02, padding='SAME', name="conv2d"):
    with tf.variable_scope(name):       
        # output_dim == Number of filters. ks == kernel size (4 x 4) s == stride, no active function.
        # Image size 0.5 times
        return slim.conv2d(input_, output_dim, ks, s, padding=padding, activation_fn=None,
                            weights_initializer=tf.truncated_normal_initializer(stddev=stddev),
                            biases_initializer=None)

# %%
def deconv2d(input_, output_dim, ks=4, s=2, stddev=0.02, name="deconv2d"):
    with tf.variable_scope(name):
       # Image size is doubled in both horizontal and vertical directions.
        return slim.conv2d_transpose(input_, output_dim, ks, s, padding='SAME', activation_fn=None,
                                    weights_initializer=tf.truncated_normal_initializer(stddev=stddev),
                                    biases_initializer=None)

# %%
# Pooling images
class ImagePool(object):
    def __init__(self, maxsize=50):
        self.maxsize = maxsize
        self.num_img = 0
        self.images = []

    def __call__(self, image):
        if self.maxsize <= 0:
            return image
        if self.num_img < self.maxsize:
            self.images.append(image)
            self.num_img += 1
            return image
        if np.random.rand() > 0.5:
            idx = int(np.random.rand()*self.maxsize)
            tmp1 = copy.copy(self.images[idx])[0]
            self.images[idx][0] = image[0]
            idx = int(np.random.rand()*self.maxsize)
            tmp2 = copy.copy(self.images[idx])[1]
            self.images[idx][1] = image[1]
            return [tmp1, tmp2]
        else:
            return image

# %%
def sce_criterion(logits, labels):
    return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))

# %%
def mae_criterion(in_, target):
    return tf.reduce_mean((in_-target)**2)

# %%
def abs_criterion(in_, target):
    return tf.reduce_mean(tf.abs(in_ - target))

# %%
def discriminator(image, options, reuse=False, name="discriminator"):

    with tf.variable_scope(name):
        # image is 256 x 256 x input_c_dim
        if reuse:
            tf.get_variable_scope().reuse_variables()
        else:
            assert tf.get_variable_scope().reuse is False

        h0 = lrelu(conv2d(image, options.df_dim, name='d_h0_conv'))
        # h0 is (128 x 128 x self.df_dim)
        h1 = lrelu(instance_norm(conv2d(h0, options.df_dim*2, name='d_h1_conv'), 'd_bn1'))
        # h1 is (64 x 64 x self.df_dim*2)
        h2 = lrelu(instance_norm(conv2d(h1, options.df_dim*4, name='d_h2_conv'), 'd_bn2'))
        # h2 is (32x 32 x self.df_dim*4)
        h3 = lrelu(instance_norm(conv2d(h2, options.df_dim*8, s=1, name='d_h3_conv'), 'd_bn3'))
        # h3 is (32 x 32 x self.df_dim*8)
        h4 = conv2d(h3, 1, s=1, name='d_h3_pred')
        # h4 is (32 x 32 x 1)
        return h4

# %%
def generator_resnet(image, options, reuse=False, name="generator"):

    with tf.variable_scope(name):
        # image is 256 x 256 x input_c_dim
        if reuse:
            tf.get_variable_scope().reuse_variables()
        else:
            assert tf.get_variable_scope().reuse is False

        def residule_block(x, dim, ks=3, s=1, name='res'):
            p = int((ks - 1) / 2)
            y = tf.pad(x, [[0, 0], [p, p], [p, p], [0, 0]], "REFLECT")      # padding is only one side up or down. p is the padding value.

            # instance_norm은 nomalization.
            y = instance_norm(conv2d(y, dim, ks, s, padding='VALID', name=name+'_c1'), name+'_bn1')
            y = tf.pad(tf.nn.relu(y), [[0, 0], [p, p], [p, p], [0, 0]], "REFLECT")
            y = instance_norm(conv2d(y, dim, ks, s, padding='VALID', name=name+'_c2'), name+'_bn2')
            return y + x            # Shouldn't you be # 1/2 ??? Doesn't matter if you normalize afterwards ...

        # Justin Johnson's model from https://github.com/jcjohnson/fast-neural-style/
        # The network with 9 blocks consists of: c7s1-32, d64, d128, R128, R128, R128,
        # R128, R128, R128, R128, R128, R128, u64, u32, c7s1-3
        c0 = tf.pad(image, [[0, 0], [3, 3], [3, 3], [0, 0]], "REFLECT")     # 3 padding up and down horizontally and vertically.
        c1 = tf.nn.relu(instance_norm(conv2d(c0, options.gf_dim, 7, 1, padding='VALID', name='g_e1_c'), 'g_e1_bn'))    # Padding is already valid.
        c2 = tf.nn.relu(instance_norm(conv2d(c1, options.gf_dim*2, 3, 2, name='g_e2_c'), 'g_e2_bn'))
        c3 = tf.nn.relu(instance_norm(conv2d(c2, options.gf_dim*4, 3, 2, name='g_e3_c'), 'g_e3_bn'))        # 64 *64

        # define G network with 9 resnet blocks
        # 18 floors total cnn.
        r1 = residule_block(c3, options.gf_dim*4, name='g_r1')
        r2 = residule_block(r1, options.gf_dim*4, name='g_r2')
        r3 = residule_block(r2, options.gf_dim*4, name='g_r3')
        r4 = residule_block(r3, options.gf_dim*4, name='g_r4')
        r5 = residule_block(r4, options.gf_dim*4, name='g_r5')
        r6 = residule_block(r5, options.gf_dim*4, name='g_r6')
        r7 = residule_block(r6, options.gf_dim*4, name='g_r7')
        r8 = residule_block(r7, options.gf_dim*4, name='g_r8')
        r9 = residule_block(r8, options.gf_dim*4, name='g_r9')

        d1 = deconv2d(r9, options.gf_dim*2, 3, 2, name='g_d1_dc')
        d1 = tf.nn.relu(instance_norm(d1, 'g_d1_bn'))
        d2 = deconv2d(d1, options.gf_dim, 3, 2, name='g_d2_dc')
        d2 = tf.nn.relu(instance_norm(d2, 'g_d2_bn'))
        d2 = tf.pad(d2, [[0, 0], [3, 3], [3, 3], [0, 0]], "REFLECT")

        # I have padded above and use 7 by 7 filter.
        pred = tf.nn.tanh(conv2d(d2, options.output_c_dim, 7, 1, padding='VALID', name='g_pred_c'))



        return pred

# %% [markdown]
# # Utils

# %%
import cv2
import scipy.misc

def imreadf(path, is_grayscale = False):
    if (is_grayscale):
        return cv2.imread(path).astype(np.float)
    else:
        return cv2.imread(path).astype(np.float)

def load_test_data(image_path, fine_size=256):
    img = imreadf(image_path)
    img = cv2.resize(img, (fine_size, fine_size))
    img = img/127.5 - 1        
    return img

def load_train_data(image_path, load_size=286, fine_size=256, is_testing=False):
    img_A = imreadf(image_path[0])
    img_B = imreadf(image_path[1])

    if not is_testing:  # 훈련 중
        img_A = cv2.resize(img_A, (load_size, load_size))
        img_B = cv2.resize(img_B, (load_size, load_size))
        h1 = int(np.ceil(np.random.uniform(1e-2, load_size-fine_size))) 
        w1 = int(np.ceil(np.random.uniform(1e-2, load_size-fine_size)))
        img_A = img_A[h1:h1+fine_size, w1:w1+fine_size]         
        img_B = img_B[h1:h1+fine_size, w1:w1+fine_size]

        if np.random.random() > 0.5:               
            img_A = np.fliplr(img_A)
            img_B = np.fliplr(img_B)

    else:   
        img_A = cv2.resize(img_A, (fine_size, fine_size))
        img_B = cv2.resize(img_B, (fine_size, fine_size))

    img_A = img_A/127.5 - 1.
    img_B = img_B/127.5 - 1.

    img_AB = np.concatenate((img_A, img_B), axis=2)
    # img_AB shape: (fine_size, fine_size, input_c_dim + output_c_dim)
    return img_AB

def get_image(image_path, image_size, is_crop=True, resize_w=64, is_grayscale = False):
    return transform(imreadf(image_path, is_grayscale), image_size, is_crop, resize_w)

def save_images(images, size, image_path):
    return imsave(inverse_transform(images), size, image_path)

def merge_images(images, size):
    return inverse_transform(images)

def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j*h:j*h+h, i*w:i*w+w, :] = image

    return img

def imsave(images, size, path):
    print('saving result to ', path)
    img=merge(images, size)
    print("log ", img.shape)
    plt.imshow(img)
    plt.savefig(path)
    return "Done"


def center_crop(x, crop_h, crop_w,
                resize_h=64, resize_w=64):
    if crop_w is None:
        crop_w = crop_h
    h, w = x.shape[:2]
    j = int(round((h - crop_h)/2.))
    i = int(round((w - crop_w)/2.))
    return cv2.resize(x[j:j+crop_h, i:i+crop_w], (resize_h, resize_w))

def transform(image, npx=64, is_crop=True, resize_w=64):
    # npx : # of pixels width/height of image
    if is_crop:
        cropped_image = center_crop(image, npx, resize_w=resize_w)
    else:
        cropped_image = image
    return np.array(cropped_image)/127.5 - 1.

def inverse_transform(images):
    return (images+1.)/2.

# %%
import cv2
i=cv2.imread('data/model_input/trainA/20_0_0_20170104230025073.jpg.chip.jpg').astype(np.float)
i.shape
# Out:
# (200, 200, 3)

# %%
v=cv2.resize(i,(256,256))

# %%
from matplotlib import pyplot as plt
import numpy as np
import cv2

def disp(path):
    from IPython.display import Image
    display(Image(filename=path) )

# %%
from PIL import Image
def disp_gen(path):
    data=cv2.imread(path)
    img=Image.fromarray(data)
    display(img)

# %% [markdown]
# # Model

# %%
class cyclegan():
    def __init__(self, sess, checkpoint_dir, test_dir, dataset_dir, which_direction, batch_size,fine_size):
        self.sess = sess
        self.batch_size = batch_size
        self.image_size = fine_size       
        self.input_c_dim = 3        
        self.output_c_dim = 3       
        self.L1_lambda = 10.0
        self.fine_size = fine_size
        self.ngf = 64         # G first conv layer filter number
        self.ndf = 64         # D first conv layer filter count
        self.output_nc = 3
        self.max_size = 50
        self.beta1 = 0.5        # adam second option
        self.epoch = 1       
        self.epoch_step = 100   # Steps to reduce # lr
        self.train_size = 1e8   # Number of images at training ??
        self.lr_init = 0.0002        # The first lr
        self.load_size = 286
        self.save_freq = 500    # Storage frequency
        self.continue_train = True         # Always train continuously.

        # Path collection
        self.checkpoint_dir = checkpoint_dir        
        self.dataset_dir = dataset_dir              
        self.test_dir = test_dir                    # The path to save the test image.

        # G and D
        self.discriminator = discriminator
        self.generator = generator_resnet  # generator using resnet

        # loss_fn
        self.original_GAN_loss = mae_criterion

        self.which_direction = which_direction

        OPTIONS = namedtuple('OPTIONS', 'batch_size image_size \
                                      gf_dim df_dim output_c_dim')
        self.options = OPTIONS._make((self.batch_size, self.fine_size,
                                      self.ngf, self.ndf, self.output_nc,))       #ngf is the number of the first conv layer filter of the generator function
                                      #self.phase == 'train'))

        self._build_model()         # Create model
        #writer = tf.train.SummaryWriter("/tmp/test_logs", sess.graph)
        self.saver = tf.train.Saver()
        self.pool = ImagePool(self.max_size)

    def _build_model(self):
        self.real_data = tf.placeholder(tf.float32,
                                        [None, self.image_size, self.image_size,
                                         self.input_c_dim + self.output_c_dim],    # input image channel and output image channel number # probably both 3. RGB.
                                        name='real_A_and_B_images')

        self.real_A = self.real_data[:, :, :, :self.input_c_dim]            # The first part of self.real_data, ie, real A
        self.real_B = self.real_data[:, :, :, self.input_c_dim:self.input_c_dim + self.output_c_dim] # real B
        self.fake_B = self.generator(self.real_A, self.options, False, name="generatorA2B")     # Replace A with a fake B.
        self.fake_A_ = self.generator(self.fake_B, self.options, False, name="generatorB2A")    # Replace fake B with fake A
        # Use predefined reuse.
        self.fake_A = self.generator(self.real_B, self.options, True, name="generatorB2A")      # Replace real B with fake A
        self.fake_B_ = self.generator(self.fake_A, self.options, True, name="generatorA2B")     # Replace fake A with fake B
        self.DB_fake = self.discriminator(self.fake_B, self.options, reuse=False, name="discriminatorB")       # 32 BY 32 comes out ..
        self.DA_fake = self.discriminator(self.fake_A, self.options, reuse=False, name="discriminatorA")

        "" "The final loss necessary to learn G & F"
        self.g_loss = self.original_GAN_loss(self.DA_fake, tf.ones_like(self.DA_fake)) \
            + self.original_GAN_loss(self.DB_fake, tf.ones_like(self.DB_fake)) \
            + self.L1_lambda * abs_criterion(self.real_A, self.fake_A_) \
            + self.L1_lambda * abs_criterion(self.real_B, self.fake_B_)

        self.fake_A_sample = tf.placeholder(tf.float32,
                                            [None, self.image_size, self.image_size,
                                             self.input_c_dim], name='fake_A_sample')
        self.fake_B_sample = tf.placeholder(tf.float32,
                                            [None, self.image_size, self.image_size,
                                             self.output_c_dim], name='fake_B_sample')

        # Put real B to get 32 by 32.
        self.DB_real = self.discriminator(self.real_B, self.options, reuse=True, name="discriminatorB")
        # Put real A to get 32 by 32.
        self.DA_real = self.discriminator(self.real_A, self.options, reuse=True, name="discriminatorA")
        ## Put a pseudo B to get 32 ​​by 32.
        self.DB_fake_sample = self.discriminator(self.fake_B_sample, self.options, reuse=True, name="discriminatorB")
        # Put a fake A to get 32 ​​by 32.
        self.DA_fake_sample = self.discriminator(self.fake_A_sample, self.options, reuse=True, name="discriminatorA")

        """ D_loss to distinguish real B from fake B """
        self.db_loss_real = self.original_GAN_loss(self.DB_real, tf.ones_like(self.DB_real))
        self.db_loss_fake = self.original_GAN_loss(self.DB_fake_sample, tf.zeros_like(self.DB_fake_sample))
        self.db_loss = (self.db_loss_real + self.db_loss_fake) / 2

        "" "D_loss distinguishes between real A and fake A" ""
        self.da_loss_real = self.original_GAN_loss(self.DA_real, tf.ones_like(self.DA_real))
        self.da_loss_fake = self.original_GAN_loss(self.DA_fake_sample, tf.zeros_like(self.DA_fake_sample))
        self.da_loss = (self.da_loss_real + self.da_loss_fake) / 2

        "" " Final loss for learning D "" "
        self.d_loss = self.da_loss + self.db_loss

        """============================================================================================"""

        """ Made for testing """
        self.test_A = tf.placeholder(tf.float32,
                                     [None, self.image_size, self.image_size,
                                      self.input_c_dim], name='test_A')
        self.test_B = tf.placeholder(tf.float32,
                                     [None, self.image_size, self.image_size,
                                      self.output_c_dim], name='test_B')
        self.testB = self.generator(self.test_A, self.options, True, name="generatorA2B")
        self.testA = self.generator(self.test_B, self.options, True, name="generatorB2A")


        """ We divide the variables when learning D and the variables when learning G. """
        t_vars = tf.trainable_variables()
        self.d_vars = [var for var in t_vars if 'discriminator' in var.name]
        self.g_vars = [var for var in t_vars if 'generator' in var.name]
#         for var in t_vars: print(var.name)

    def train(self):
        """Train cyclegan"""
        self.lr_var = tf.placeholder(tf.float32, None, name='learning_rate')
        self.d_optim = tf.train.AdamOptimizer(self.lr_var, beta1=self.beta1) \
            .minimize(self.d_loss, var_list=self.d_vars)
        self.g_optim = tf.train.AdamOptimizer(self.lr_var, beta1=self.beta1) \
            .minimize(self.g_loss, var_list=self.g_vars)

        """
        #########################################################
        self.hyunbo_optim = tf.train.AdamOptimizer(self.lr_var, beta1=self.beta1) \
            .minimize(self.g_loss_by_hyunbo, var_list=self.g_vars)
        #########################################################
        """

        init_op = tf.global_variables_initializer()    # Initialize all variables.
        self.sess.run(init_op)

        counter = 1
        start_time = time.time()

        if self.continue_train:
            suc_or_fal, num_of_train = self.load()         
            if suc_or_fal:
                print(" check point Import succeeded")
                counter = int(num_of_train.split('-')[1])                    # To save the next one ..
            else:
                print(" Failed to fetch check point")

        for epoch in range(self.epoch):
            dataA = glob('{}/*.*'.format(self.dataset_dir + '/trainA'))
            dataB = glob('{}/*.*'.format(self.dataset_dir + '/trainB'))
#             print("num of dataA : ", dataA.__len__())
#             print("num of dataB : ", dataB.__len__())
            np.random.shuffle(dataA)
            np.random.shuffle(dataB)
            batch_idxs = min(min(len(dataA), len(dataB)), self.train_size) // self.batch_size
            print("epoch starting for bs", self.batch_size)
            print("Number of mini batches :: ", batch_idxs)
            start_time = time.time()
            lr = self.lr_init if epoch < self.epoch_step else self.lr_init*(self.epoch-epoch)/(self.epoch-self.epoch_step)    

            for idx in range(0, batch_idxs):
                batch_files = list(zip(dataA[idx * self.batch_size:(idx + 1) * self.batch_size],
                                       dataB[idx * self.batch_size:(idx + 1) * self.batch_size]))
                # Change image size.
                batch_images = [load_train_data(batch_file, self.load_size, self.fine_size) for batch_file in batch_files] 
                batch_images = np.array(batch_images).astype(np.float32)
#                 print("batch_images", batch_images.shape)
                print(".", end="")
    
                # Update G network and record fake outputs
                fake_A, fake_B, _ = self.sess.run(
                    [self.fake_A, self.fake_B, self.g_optim],
                    feed_dict={self.real_data: batch_images, self.lr_var: lr})

                #self.writer.add_summary(summary_str, counter)
                #[fake_A, fake_B] = self.pool([fake_A, fake_B])

                # Update D network
                self.sess.run( [self.d_optim],
                               feed_dict={self.real_data: batch_images,
                                    self.fake_A_sample: fake_A,
                                    self.fake_B_sample: fake_B,
                                    self.lr_var: lr})
                #self.writer.add_summary(summary_str, counter)

                counter += 1

                # Save.
                if np.mod(counter, self.save_freq) == 2:
                    self.save(counter)
                    print("\n ckpt saved ", counter)
            print(("\n Epoch: [%2d] [%4d/%4d] time: %4.4f" % (epoch, idx, batch_idxs, time.time() - start_time)))

    def save(self, step):

        step_str = str(step)

        self.saver.save(self.sess,
                        self.checkpoint_dir + "/" + step_str,
                        global_step=step)



    def load(self):
        print(" [*] Reading checkpoint...")

        #model_dir = "%s_%s" % (self.dataset_dir, self.image_size)
        #checkpoint_dir = os.path.join(checkpoint_dir, model_dir)

        ckpt = tf.train.get_checkpoint_state(self.checkpoint_dir)
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
            self.saver.restore(self.sess, os.path.join(self.checkpoint_dir, ckpt_name))
            print(" Checkpoint name !! :", ckpt_name)
            index = ckpt_name.find("-")
            num_of_train = ckpt_name[index + 1:]
            print(" Number of invoked ckpt:", num_of_train)
            time.sleep(10)
            return True, ckpt_name
        else:
            print("check point Is not in the path.")
            return False, 1             

    def test(self):
        """Test cyclegan"""
        init_op = tf.global_variables_initializer()
        self.sess.run(init_op)
        if self.which_direction == 'AtoB':
            sample_files = glob('{}/*.*'.format(self.dataset_dir + '/testA'))
            print("dataset Import succeeded.")
        elif self.which_direction == 'BtoA':
            sample_files = glob('{}/*.*'.format(self.dataset_dir + '/testB'))
            print("dataset Import succeeded.")
        else:
            raise Exception('AtoB BtoA Please choose one of them.')

        if self.load():
            print(" check point Import succeeded")
        else:
            print(" check point Import failed")

        if self.which_direction == 'AtoB':
            out_var, in_var = (self.testB, self.test_A)
        else:
            out_var, in_var = (self.testA, self.test_B)

        print (len(sample_files))
        for sample_file in sample_files:
            print('Processing image: ' + sample_file)
            sample_image = [load_test_data(sample_file, self.fine_size)]
            sample_image = np.array(sample_image).astype(np.float32)
            image_path = os.path.join(self.test_dir,
                                      '{0}_{1}'.format(self.which_direction, os.path.basename(sample_file)))
            fake_img = self.sess.run(out_var, feed_dict={in_var: sample_image})
            print("start saving")
            save_images(fake_img, [1, 1], image_path)

# %% [markdown]
# # Training

# %%
def run(phase,checkpoint_dir,which_direction="B2A",batch_size=32,fine_size=256,epoch=5):
    checkpoint_dir=checkpoint_dir
    test_dir = './test'                      
    dataset_dir = './data/gender_model_input/'               
    phase = phase  # or test
    which_direction = which_direction  # or BtoA
    batch_size=batch_size
    fine_size=fine_size
    epoch=epoch

    def createDir(direc):
        if not os.path.exists(direc):
            os.makedirs(direc)
            
    createDir(test_dir)
    createDir(dataset_dir)
    createDir(checkpoint_dir)
    
    tfconfig = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)        # Using GPU
    tfconfig.gpu_options.allow_growth = True
    
    tf.reset_default_graph() #Reset the old tf graphs on gpu
    
    with tf.Session(config=tfconfig) as sess:
        model = cyclegan(sess, checkpoint_dir = checkpoint_dir, test_dir = test_dir,\
                         dataset_dir= dataset_dir, which_direction= which_direction, batch_size=batch_size,fine_size=fine_size)
        model.epoch=epoch
        if phase == 'train':
            print("Training ")
            model.train()
        elif phase == "test":
            print(" Testing")
            model.test()
        else:
            print(" train??? test????")

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=32,fine_size=48,epoch=10)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0817 19:40:51.907204 140281583462144 deprecation.py:506] From <ipython-input-8-b7e5f33d89e9>:6: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0817 19:40:55.941400 140281583462144 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Training
# W0817 19:41:12.152315 140281583462144 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
#  [*] Reading checkpoint...
#  Checkpoint name !! : 32002-32002
#  Number of invoked ckpt: 32002
#  check point Import succeeded
# epoch starting for bs 32
# Number of mini batches ::  147
# .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-890532fdafdc> in <module>
# ----> 1 run("train",'./checkpoint/gender/trail_1' ,batch_size=32,fine_size=48,epoch=10)
#
# <ipython-input-23-574c821f0deb> in run(phase, checkpoint_dir, which_direction, batch_size, fine_size, epoch)
#      28         if phase == 'train':
#      29             print("Training ")
# ---> 30             model.train()
#      31         elif phase == "test":
#      32             print(" Testing")
#
# <ipython-input-22-402a4751b207> in train(self)
#     190                                     self.fake_A_sample: fake_A,
#     191                                     self.fake_B_sample: fake_B,
# --> 192                                     self.lr_var: lr})
#     193                 #self.writer.add_summary(summary_str, counter)
#     194
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     948     try:
#     949       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 950                          run_metadata_ptr)
#     951       if run_metadata:
#     952         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1171     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1172       results = self._do_run(handle, final_targets, final_fetches,
# -> 1173                              feed_dict_tensor, options, run_metadata)
#    1174     else:
#    1175       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1348     if handle is None:
#    1349       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1350                            run_metadata)
#    1351     else:
#    1352       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1354   def _do_call(self, fn, *args):
#    1355     try:
# -> 1356       return fn(*args)
#    1357     except errors.OpError as e:
#    1358       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1339       self._extend_graph()
#    1340       return self._call_tf_sessionrun(
# -> 1341           options, feed_dict, fetch_list, target_list, run_metadata)
#    1342
#    1343     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1427     return tf_session.TF_SessionRun_wrapper(
#    1428         self._session, options, feed_dict, fetch_list, target_list,
# -> 1429         run_metadata)
#    1430
#    1431   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=32,fine_size=48,epoch=10)
# Out:
# Training
# W0817 08:34:14.269272 139744225535744 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
#  [*] Reading checkpoint...
#  Checkpoint name !! : 1002-1002
#  Number of invoked ckpt: 1002
#  check point Import succeeded
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 0] [ 146/ 147] time: 136.1312
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 1] [ 146/ 147] time: 122.6894
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 2] [ 146/ 147] time: 122.5528
# epoch starting for bs 32
# Number of mini batches ::  147
# ...........................................................
#  ckpt saved  1502
# ........................................................................................
#  Epoch: [ 3] [ 146/ 147] time: 125.0131
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 4] [ 146/ 147] time: 122.3845
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 5] [ 146/ 147] time: 122.3820
# epoch starting for bs 32
# Number of mini batches ::  147
# ......................................................................................................................
#  ckpt saved  2002
# .............................
#  Epoch: [ 6] [ 146/ 147] time: 123.8393
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 7] [ 146/ 147] time: 122.2691
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 8] [ 146/ 147] time: 122.1426
# epoch starting for bs 32
# Number of mini batches ::  147
# ...................................................................................................................................................
#  Epoch: [ 9] [ 146/ 147] time: 122.1755

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=18,fine_size=64,epoch=20)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 2002-2002
#  Number of invoked ckpt: 2002
#  check point Import succeeded
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 0] [ 261/ 262] time: 230.2288
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................................................................................................................................................................
#  ckpt saved  2502
# ........................
#  Epoch: [ 1] [ 261/ 262] time: 219.4680
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 2] [ 261/ 262] time: 216.9407
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................
#  ckpt saved  3002
# ................................................
#  Epoch: [ 3] [ 261/ 262] time: 218.4260
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 4] [ 261/ 262] time: 216.8051
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................................................................................................................
#  ckpt saved  3502
# ........................................................................
#  Epoch: [ 5] [ 261/ 262] time: 218.3817
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 6] [ 261/ 262] time: 216.8687
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................
#  ckpt saved  4002
# ................................................................................................
#  Epoch: [ 7] [ 261/ 262] time: 218.4347
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 8] [ 261/ 262] time: 216.8607
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................................................................
#  ckpt saved  4502
# ........................................................................................................................
#  Epoch: [ 9] [ 261/ 262] time: 218.3320
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [10] [ 261/ 262] time: 216.8570
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................
# W0817 09:37:23.757704 139744225535744 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
#  ckpt saved  5002
# ................................................................................................................................................
#  Epoch: [11] [ 261/ 262] time: 218.3094
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [12] [ 261/ 262] time: 216.8347
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................
#  ckpt saved  5502
# ........................................................................................................................................................................
#  Epoch: [13] [ 261/ 262] time: 218.4499
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [14] [ 261/ 262] time: 216.8910
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................
#  ckpt saved  6002
# ................................................................................................................................................................................................
#  Epoch: [15] [ 261/ 262] time: 218.4436
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [16] [ 261/ 262] time: 216.8451
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................
#  ckpt saved  6502
# ........................................................................................................................................................................................................................
#  Epoch: [17] [ 261/ 262] time: 218.5483
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [18] [ 261/ 262] time: 216.8298
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................
#  ckpt saved  7002
# ................................................................................................................................................................................................................................................
#  Epoch: [19] [ 261/ 262] time: 218.4898

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=18,fine_size=64,epoch=20)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 7002-7002
#  Number of invoked ckpt: 7002
#  check point Import succeeded
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 0] [ 261/ 262] time: 231.6773
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................................................................................................................................................................
#  ckpt saved  7502
# ........................
#  Epoch: [ 1] [ 261/ 262] time: 219.6721
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 2] [ 261/ 262] time: 217.3542
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................
#  ckpt saved  8002
# ................................................
#  Epoch: [ 3] [ 261/ 262] time: 218.7483
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 4] [ 261/ 262] time: 217.1933
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................................................................................................................
#  ckpt saved  8502
# ........................................................................
#  Epoch: [ 5] [ 261/ 262] time: 218.6117
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 6] [ 261/ 262] time: 217.2316
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................
#  ckpt saved  9002
# ................................................................................................
#  Epoch: [ 7] [ 261/ 262] time: 218.7206
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [ 8] [ 261/ 262] time: 217.1541
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................................................................
#  ckpt saved  9502
# ........................................................................................................................
#  Epoch: [ 9] [ 261/ 262] time: 218.8529
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [10] [ 261/ 262] time: 217.1758
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................
#  ckpt saved  10002
# ................................................................................................................................................
#  Epoch: [11] [ 261/ 262] time: 218.4725
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [12] [ 261/ 262] time: 216.8950
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................................................................
#  ckpt saved  10502
# ........................................................................................................................................................................
#  Epoch: [13] [ 261/ 262] time: 218.5096
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [14] [ 261/ 262] time: 216.8848
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................
#  ckpt saved  11002
# ................................................................................................................................................................................................
#  Epoch: [15] [ 261/ 262] time: 218.4142
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [16] [ 261/ 262] time: 216.9423
# epoch starting for bs 18
# Number of mini batches ::  262
# ..............................................
#  ckpt saved  11502
# ........................................................................................................................................................................................................................
#  Epoch: [17] [ 261/ 262] time: 218.4910
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................................................................................................................................................................................................................................................................
#  Epoch: [18] [ 261/ 262] time: 216.8833
# epoch starting for bs 18
# Number of mini batches ::  262
# ......................
#  ckpt saved  12002
# ................................................................................................................................................................................................................................................
#  Epoch: [19] [ 261/ 262] time: 218.4883

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=9,fine_size=96,epoch=20)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 12002-12002
#  Number of invoked ckpt: 12002
#  check point Import succeeded
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  12502
# ........................
#  Epoch: [ 0] [ 523/ 524] time: 476.7833
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  13002
# ................................................
#  Epoch: [ 1] [ 523/ 524] time: 462.5199
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  13502
# ........................................................................
#  Epoch: [ 2] [ 523/ 524] time: 462.9730
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  14002
# ................................................................................................
#  Epoch: [ 3] [ 523/ 524] time: 462.7286
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  14502
# ........................................................................................................................
#  Epoch: [ 4] [ 523/ 524] time: 462.9888
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  15002
# ................................................................................................................................................
#  Epoch: [ 5] [ 523/ 524] time: 463.1098
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  15502
# ........................................................................................................................................................................
#  Epoch: [ 6] [ 523/ 524] time: 463.2473
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  16002
# ................................................................................................................................................................................................
#  Epoch: [ 7] [ 523/ 524] time: 463.3516
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................
#  ckpt saved  16502
# ........................................................................................................................................................................................................................
#  Epoch: [ 8] [ 523/ 524] time: 463.2934
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................
#  ckpt saved  17002
# ................................................................................................................................................................................................................................................
#  Epoch: [ 9] [ 523/ 524] time: 463.0945
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................
#  ckpt saved  17502
# ........................................................................................................................................................................................................................................................................
#  Epoch: [10] [ 523/ 524] time: 463.2950
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................
#  ckpt saved  18002
# ................................................................................................................................................................................................................................................................................................
#  Epoch: [11] [ 523/ 524] time: 463.0710
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................
#  ckpt saved  18502
# ........................................................................................................................................................................................................................................................................................................................
#  Epoch: [12] [ 523/ 524] time: 463.0829
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................
#  ckpt saved  19002
# ................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [13] [ 523/ 524] time: 462.9128
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................
#  ckpt saved  19502
# ........................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [14] [ 523/ 524] time: 462.9119
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................
#  ckpt saved  20002
# ................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [15] [ 523/ 524] time: 462.8040
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................
#  ckpt saved  20502
# ........................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [16] [ 523/ 524] time: 462.7875
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................
#  ckpt saved  21002
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [17] [ 523/ 524] time: 462.8318
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................
#  ckpt saved  21502
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [18] [ 523/ 524] time: 462.7239
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................
#  ckpt saved  22002
# ...............................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [19] [ 523/ 524] time: 462.7428

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=9,fine_size=96,epoch=20)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 22002-22002
#  Number of invoked ckpt: 22002
#  check point Import succeeded
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  22502
# ........................
#  Epoch: [ 0] [ 523/ 524] time: 477.4379
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  23002
# ................................................
#  Epoch: [ 1] [ 523/ 524] time: 463.3869
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  23502
# ........................................................................
#  Epoch: [ 2] [ 523/ 524] time: 463.5400
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  24002
# ................................................................................................
#  Epoch: [ 3] [ 523/ 524] time: 463.5705
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  24502
# ........................................................................................................................
#  Epoch: [ 4] [ 523/ 524] time: 463.5647
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  25002
# ................................................................................................................................................
#  Epoch: [ 5] [ 523/ 524] time: 463.4313
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  25502
# ........................................................................................................................................................................
#  Epoch: [ 6] [ 523/ 524] time: 463.7693
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  26002
# ................................................................................................................................................................................................
#  Epoch: [ 7] [ 523/ 524] time: 463.7839
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................................................................
#  ckpt saved  26502
# ........................................................................................................................................................................................................................
#  Epoch: [ 8] [ 523/ 524] time: 463.5106
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................................................................
#  ckpt saved  27002
# ................................................................................................................................................................................................................................................
#  Epoch: [ 9] [ 523/ 524] time: 463.5287
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................................................................
#  ckpt saved  27502
# ........................................................................................................................................................................................................................................................................
#  Epoch: [10] [ 523/ 524] time: 463.4752
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................................................................
#  ckpt saved  28002
# ................................................................................................................................................................................................................................................................................................
#  Epoch: [11] [ 523/ 524] time: 463.3318
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................................................................
#  ckpt saved  28502
# ........................................................................................................................................................................................................................................................................................................................
#  Epoch: [12] [ 523/ 524] time: 463.4946
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................................................................
#  ckpt saved  29002
# ................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [13] [ 523/ 524] time: 463.5110
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................................................................
#  ckpt saved  29502
# ........................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [14] [ 523/ 524] time: 463.6222
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................................................................
#  ckpt saved  30002
# ................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [15] [ 523/ 524] time: 463.5471
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................................................................
#  ckpt saved  30502
# ........................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [16] [ 523/ 524] time: 463.6540
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................................................................
#  ckpt saved  31002
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [17] [ 523/ 524] time: 463.4182
# epoch starting for bs 9
# Number of mini batches ::  524
# ....................................................................
#  ckpt saved  31502
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [18] [ 523/ 524] time: 463.5221
# epoch starting for bs 9
# Number of mini batches ::  524
# ............................................
#  ckpt saved  32002
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [19] [ 523/ 524] time: 463.2965

# %%
run("test",'./checkpoint/gender/trail_1',which_direction="AtoB")
# Out:
#  Testing
# dataset Import succeeded.
#  [*] Reading checkpoint...
#  Checkpoint name !! : 21002-21002
#  Number of invoked ckpt: 21002
#  check point Import succeeded
# 3
# Processing image: ./data/ethnicity_model_input//testA/21_0_3_20170119150216454.jpg.chip.jpg
# start saving
# saving result to  ./test/AtoB_21_0_3_20170119150216454.jpg.chip.jpg
# log  (256, 256, 3)
# Processing image: ./data/ethnicity_model_input//testA/KakaoTalk_20181212_013947907.jpg
# start saving
# saving result to  ./test/AtoB_KakaoTalk_20181212_013947907.jpg
# log  (256, 256, 3)
# Processing image: ./data/ethnicity_model_input//testA/21_1_2_20170116171134381.jpg.chip.jpg
# start saving
# saving result to  ./test/AtoB_21_1_2_20170116171134381.jpg.chip.jpg
# log  (256, 256, 3)

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=1,fine_size=256,epoch=5)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 30502-30502
#  Number of invoked ckpt: 30502
#  check point Import succeeded
# epoch starting for bs 1
# Number of mini batches ::  4526
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  31002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  31502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  32002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  32502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  33002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  33502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  34002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  34502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  35002
# ..........................
#  Epoch: [ 0] [4525/4526] time: 3109.6118
# epoch starting for bs 1
# Number of mini batches ::  4526
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  35502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  36002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  36502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  37002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  37502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  38002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  38502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  39002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  39502
# ....................................................
#  Epoch: [ 1] [4525/4526] time: 3095.9739
# epoch starting for bs 1
# Number of mini batches ::  4526
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  40002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  40502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  41002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  41502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  42002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  42502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  43002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  43502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  44002
# ..............................................................................
#  Epoch: [ 2] [4525/4526] time: 3096.5544
# epoch starting for bs 1
# Number of mini batches ::  4526
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  44502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  45002
# ......................................................................................................................................

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=8,fine_size=96,epoch=10)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 32002-32002
#  Number of invoked ckpt: 32002
#  check point Import succeeded
# epoch starting for bs 8
# Number of mini batches ::  590
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  32502
# ..........................................................................................
#  Epoch: [ 0] [ 589/ 590] time: 582.9757
# epoch starting for bs 8
# Number of mini batches ::  590
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  33002
# ....................................................................................................................................................................................
#  Epoch: [ 1] [ 589/ 590] time: 466.5933
# epoch starting for bs 8
# Number of mini batches ::  590
# ................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  33502
# ..............................................................................................................................................................................................................................................................................
#  Epoch: [ 2] [ 589/ 590] time: 463.6726
# epoch starting for bs 8
# Number of mini batches ::  590
# ......................................................................................................................................................................................................................................
#  ckpt saved  34002
# ........................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 3] [ 589/ 590] time: 463.4368
# epoch starting for bs 8
# Number of mini batches ::  590
# ............................................................................................................................................
#  ckpt saved  34502
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 4] [ 589/ 590] time: 463.4742
# epoch starting for bs 8
# Number of mini batches ::  590
# ..................................................
# W0817 20:29:14.309023 140281583462144 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:960: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
#  ckpt saved  35002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  35502
# ........................................
#  Epoch: [ 5] [ 589/ 590] time: 464.7566
# epoch starting for bs 8
# Number of mini batches ::  590
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  36002
# ..................................................................................................................................
#  Epoch: [ 6] [ 589/ 590] time: 463.5544
# epoch starting for bs 8
# Number of mini batches ::  590
# ..................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  36502
# ............................................................................................................................................................................................................................
#  Epoch: [ 7] [ 589/ 590] time: 463.4257
# epoch starting for bs 8
# Number of mini batches ::  590
# ........................................................................................................................................................................................................................................................................................
#  ckpt saved  37002
# ......................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 8] [ 589/ 590] time: 463.3580
# epoch starting for bs 8
# Number of mini batches ::  590
# ..............................................................................................................................................................................................
#  ckpt saved  37502
# ................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 9] [ 589/ 590] time: 463.2074

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=8,fine_size=96,epoch=30)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 37502-37502
#  Number of invoked ckpt: 37502
#  check point Import succeeded
# epoch starting for bs 8
# Number of mini batches ::  590
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  38002
# ..........................................................................................
#  Epoch: [ 0] [ 589/ 590] time: 475.4295
# epoch starting for bs 8
# Number of mini batches ::  590
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  38502
# ....................................................................................................................................................................................
#  Epoch: [ 1] [ 589/ 590] time: 462.1138
# epoch starting for bs 8
# Number of mini batches ::  590
# ................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  39002
# ..............................................................................................................................................................................................................................................................................
#  Epoch: [ 2] [ 589/ 590] time: 462.1460
# epoch starting for bs 8
# Number of mini batches ::  590
# ......................................................................................................................................................................................................................................
#  ckpt saved  39502
# ........................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 3] [ 589/ 590] time: 461.8191
# epoch starting for bs 8
# Number of mini batches ::  590
# ............................................................................................................................................
#  ckpt saved  40002
# ..................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 4] [ 589/ 590] time: 462.0018
# epoch starting for bs 8
# Number of mini batches ::  590
# ..................................................
#  ckpt saved  40502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  41002
# ........................................
#  Epoch: [ 5] [ 589/ 590] time: 463.6347
# epoch starting for bs 8
# Number of mini batches ::  590
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  41502
# ..................................................................................................................................
#  Epoch: [ 6] [ 589/ 590] time: 461.9339
# epoch starting for bs 8
# Number of mini batches ::  590
# ..................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  42002
# ............................................................................................................................................................................................................................
#  Epoch: [ 7] [ 589/ 590] time: 461.9685
# epoch starting for bs 8
# Number of mini batches ::  590
# ........................................................................................................................................................................................................................................................................................
#  ckpt saved  42502
# ......................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 8] [ 589/ 590] time: 462.0082
# epoch starting for bs 8
# Number of mini batches ::  590
# ..............................................................................................................................................................................................
#  ckpt saved  43002
# ................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 9] [ 589/ 590] time: 462.1286
# epoch starting for bs 8
# Number of mini batches ::  590
# ....................................................................................................
#  ckpt saved  43502
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [10] [ 589/ 590] time: 462.1459
# epoch starting for bs 8
# Number of mini batches ::  590
# ..........
#  ckpt saved  44002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  44502
# ................................................................................
#  Epoch: [11] [ 589/ 590] time: 463.9307
# epoch starting for bs 8
# Number of mini batches ::  590
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  45002
# ..........................................................................................................................................................................
#  Epoch: [12] [ 589/ 590] time: 462.0190
# epoch starting for bs 8
# Number of mini batches ::  590
# ..........................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  45502
# ....................................................................................................................................................................................................................................................................
#  Epoch: [13] [ 589/ 590] time: 462.0509
# epoch starting for bs 8
# Number of mini batches ::  590
# ................................................................................................................................................................................................................................................
#  ckpt saved  46002
# ..............................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [14] [ 589/ 590] time: 462.1388
# epoch starting for bs 8
# Number of mini batches ::  590
# ......................................................................................................................................................
#  ckpt saved  46502
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [15] [ 589/ 590] time: 462.1201
# epoch starting for bs 8
# Number of mini batches ::  590
# ............................................................
#  ckpt saved  47002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  47502
# ..............................
#  Epoch: [16] [ 589/ 590] time: 463.4258
# epoch starting for bs 8
# Number of mini batches ::  590
# ......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  48002
# ........................................................................................................................
#  Epoch: [17] [ 589/ 590] time: 462.1297
# epoch starting for bs 8
# Number of mini batches ::  590
# ............................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  48502
# ..................................................................................................................................................................................................................
#  Epoch: [18] [ 589/ 590] time: 462.0144
# epoch starting for bs 8
# Number of mini batches ::  590
# ..................................................................................................................................................................................................................................................................................................
#  ckpt saved  49002
# ............................................................................................................................................................................................................................................................................................................
#  Epoch: [19] [ 589/ 590] time: 461.8801
# epoch starting for bs 8
# Number of mini batches ::  590
# ........................................................................................................................................................................................................
#  ckpt saved  49502
# ......................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [20] [ 589/ 590] time: 462.0890
# epoch starting for bs 8
# Number of mini batches ::  590
# ..............................................................................................................
#  ckpt saved  50002
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [21] [ 589/ 590] time: 461.8108
# epoch starting for bs 8
# Number of mini batches ::  590
# ....................
#  ckpt saved  50502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  51002
# ......................................................................
#  Epoch: [22] [ 589/ 590] time: 463.6660
# epoch starting for bs 8
# Number of mini batches ::  590
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  51502
# ................................................................................................................................................................
#  Epoch: [23] [ 589/ 590] time: 461.9628
# epoch starting for bs 8
# Number of mini batches ::  590
# ....................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  52002
# ..........................................................................................................................................................................................................................................................
#  Epoch: [24] [ 589/ 590] time: 461.9321
# epoch starting for bs 8
# Number of mini batches ::  590
# ..........................................................................................................................................................................................................................................................
#  ckpt saved  52502
# ....................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [25] [ 589/ 590] time: 461.9586
# epoch starting for bs 8
# Number of mini batches ::  590
# ................................................................................................................................................................
#  ckpt saved  53002
# ..............................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [26] [ 589/ 590] time: 462.0421
# epoch starting for bs 8
# Number of mini batches ::  590
# ......................................................................
#  ckpt saved  53502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  54002
# ....................
#  Epoch: [27] [ 589/ 590] time: 463.4395
# epoch starting for bs 8
# Number of mini batches ::  590
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  54502
# ..............................................................................................................
#  Epoch: [28] [ 589/ 590] time: 461.9881
# epoch starting for bs 8
# Number of mini batches ::  590
# ......................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  55002
# ........................................................................................................................................................................................................
#  Epoch: [29] [ 589/ 590] time: 461.8189

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=2,fine_size=128,epoch=10)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 55002-55002
#  Number of invoked ckpt: 55002
#  check point Import succeeded
# epoch starting for bs 2
# Number of mini batches ::  2360
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  55502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  56002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  56502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  57002
# ........................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 0] [2359/2360] time: 1001.1227
# epoch starting for bs 2
# Number of mini batches ::  2360
# ............................................................................................................................................
#  ckpt saved  57502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  58002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  58502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  59002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  59502
# ............................................................................................................................................................................................................................
#  Epoch: [ 1] [2359/2360] time: 989.5058
# epoch starting for bs 2
# Number of mini batches ::  2360
# ........................................................................................................................................................................................................................................................................................
#  ckpt saved  60002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  60502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  61002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  61502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  62002
# ................................................................................
#  Epoch: [ 2] [2359/2360] time: 989.4615
# epoch starting for bs 2
# Number of mini batches ::  2360
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  62502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  63002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  63502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  64002
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 3] [2359/2360] time: 988.5696
# epoch starting for bs 2
# Number of mini batches ::  2360
# ............................................................
#  ckpt saved  64502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  65002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  65502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  66002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  66502
# ............................................................................................................................................................................................................................................................................................................
#  Epoch: [ 4] [2359/2360] time: 990.2350
# epoch starting for bs 2
# Number of mini batches ::  2360
# ........................................................................................................................................................................................................
#  ckpt saved  67002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  67502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  68002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  68502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  69002
# ................................................................................................................................................................
#  Epoch: [ 5] [2359/2360] time: 990.0587
# epoch starting for bs 2
# Number of mini batches ::  2360
# ....................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  69502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  70002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  70502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  71002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  71502
# ....................
#  Epoch: [ 6] [2359/2360] time: 990.1441
# epoch starting for bs 2
# Number of mini batches ::  2360
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  72002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  72502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  73002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  73502
# ............................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 7] [2359/2360] time: 988.6823
# epoch starting for bs 2
# Number of mini batches ::  2360
# ........................................................................................................................
#  ckpt saved  74002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  74502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  75002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  75502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  76002
# ................................................................................................................................................................................................................................................
#  Epoch: [ 8] [2359/2360] time: 990.4222
# epoch starting for bs 2
# Number of mini batches ::  2360
# ....................................................................................................................................................................................................................................................................
#  ckpt saved  76502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  77002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  77502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  78002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  78502
# ....................................................................................................
#  Epoch: [ 9] [2359/2360] time: 989.7474

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=1,fine_size=256,epoch=10)
# Out:
# Training
#  [*] Reading checkpoint...
#  Checkpoint name !! : 78502-78502
#  Number of invoked ckpt: 78502
#  check point Import succeeded
# epoch starting for bs 1
# Number of mini batches ::  4720
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  79002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  79502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  80002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  80502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  81002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  81502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  82002
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  82502
# ...........................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  83002
# ............................................................................................................................................................................................................................
#  Epoch: [ 0] [4719/4720] time: 3220.2051
# epoch starting for bs 1
# Number of mini batches ::  4720
# ........................................................................................................................................................................................................................................................................................
#  ckpt saved  83502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  84002
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  84502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  85002
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  85502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  86002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  86502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  87002
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  87502
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 1] [4719/4720] time: 3205.0332
# epoch starting for bs 1
# Number of mini batches ::  4720
# ............................................................
#  ckpt saved  88002
# .............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  88502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  89002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  89502
# ...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  90502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  91002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  91502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  92002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  92502
# ................................................................................................................................................................
#  Epoch: [ 2] [4719/4720] time: 3208.4786
# epoch starting for bs 1
# Number of mini batches ::  4720
# ....................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  93002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  93502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  94002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  94502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  95002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  95502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  96002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  96502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  97002
# ............................................................................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 3] [4719/4720] time: 3213.7140
# epoch starting for bs 1
# Number of mini batches ::  4720
# ........................................................................................................................
#  ckpt saved  97502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  98002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  98502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  99002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  99502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  100002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  100502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  101002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  101502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  102002
# ....................................................................................................
#  Epoch: [ 4] [4719/4720] time: 3207.4170
# epoch starting for bs 1
# Number of mini batches ::  4720
# ................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  102502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  103002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  103502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  104002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  104502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  105002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  105502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  106002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  106502
# ................................................................................................................................................................................................................................................................................................................................
#  Epoch: [ 5] [4719/4720] time: 3209.7042
# epoch starting for bs 1
# Number of mini batches ::  4720
# ....................................................................................................................................................................................
#  ckpt saved  107002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  107502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  108002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  108502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  109002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  109502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  110002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  110502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  111002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  111502
# ........................................
#  Epoch: [ 6] [4719/4720] time: 3213.0870
# epoch starting for bs 1
# Number of mini batches ::  4720
# ............................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  112002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  112502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  113002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  113502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  114002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  114502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  115002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  115502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  116002
# ....................................................................................................................................................................................................................................................................
#  Epoch: [ 7] [4719/4720] time: 3212.8224
# epoch starting for bs 1
# Number of mini batches ::  4720
# ................................................................................................................................................................................................................................................
#  ckpt saved  116502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  117002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  117502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  118002
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  118502
# ....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#  ckpt saved  119002
# .............................................................................................................................................................................................................................................

# %%
run("train",'./checkpoint/gender/trail_1' ,batch_size=1,fine_size=256,epoch=30)
